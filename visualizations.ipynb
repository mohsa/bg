# %%
import os
import cv2
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

from Data_generator_epoch import epoch_data

# %% [markdown]
# # Bugs Removed:
#
# There were couple of bugs in the code, which were removed. Now input to the network looks like this.... the offset range is (-10,10)

# %%
X_train, Y_train, X_val, Y_val, input1, input_perturbed = epoch_data()

print('='*50)   
for i in range(6):
    nn = np.random.randint(1,50)
    plt.figure()
    plt.subplot(1,2,1)
    plt.title('input image1')
    plt.imshow(X_train[nn][:,:,0], cmap = 'gray',)
    print('offsets:', Y_train[nn])
    plt.subplot(1,2,2)
    plt.title('input image perturbed')
    plt.imshow(X_train[nn][:,:,1],  cmap=plt.get_cmap('gray'))
    plt.show()
# Out:
# total samles: 148
# [[-8. -6. -7. ..., -9. -8. -9.]
#  [ 3.  5.  2. ..., -2.  3. -2.]
#  [ 9. -7. -9. ..., -3.  9. -3.]
#  ...,
#  [-4. -3.  4. ..., -3. -4. -3.]
#  [ 3. -1. -7. ..., -4.  3. -4.]
#  [-2.  2. -9. ...,  3. -2.  3.]]
# ...
# offsets: [ 6. -4. -2. -4.  6.  5.  6.  5.]
# offsets: [ 2.  8. -2.  8.  2. -9.  2. -9.]
# offsets: [-1.  9.  9.  9. -1. -2. -1. -2.]
# offsets: [ 2.  8. -2.  8.  2. -9.  2. -9.]
# offsets: [ 1. -4.  3. -4.  1.  6.  1.  6.]
# offsets: [ 6. -4. -2. -4.  6.  5.  6.  5.]

# %% [markdown]
# And a validation sample

# %%
plt.figure()
plt.subplot(1,2,1)
plt.imshow(X_val[1][:,:,0], cmap = 'gray')
plt.subplot(1,2,2)
plt.imshow(X_val[1][:,:,1],  cmap=plt.get_cmap('gray'))
plt.show()

# %% [markdown]
# # Training and testing
# Netwoek is trained on just 80 images. Some of the results ..... far from perfect.
#
# Network is small with one convolutional and 2 dense layers.
#
# In results a given image and its distorted version in shown. then predicted image is overlaid on the ground truth image. Finally, predicted image is overlaid on the original image.

# %%
from pano_data_data import pano_data
from test_pano import panorama
# Out:
# Using Theano backend.

# %%
panorama()
# Out:
# /home/saif/signality_codes/test/homography/deep_homography_estimation_dg.py:59: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (3, 3), input_shape=(288, 512,..., kernel_initializer="glorot_uniform", activation="relu")`
#   model.add(Convolution2D(c, 3, 3, input_shape=(patch_height, patch_width, ch), activation='relu',init='glorot_uniform'))
# /home/saif/signality_codes/test/homography/deep_homography_estimation_dg.py:60: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), kernel_initializer="glorot_uniform", activation="relu")`
#   model.add(Convolution2D(c*2, 3, 3, activation='relu',init='glorot_uniform'))
# /home/saif/signality_codes/test/homography/deep_homography_estimation_dg.py:81: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(128, kernel_initializer="glorot_uniform", activation="relu")`
#   model.add(Dense(128, activation='relu',init='glorot_uniform'))
# ...

# %%
panorama()
# Out:
# /home/saif/signality_codes/test/homography/deep_homography_estimation_dg.py:59: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (3, 3), input_shape=(288, 512,..., kernel_initializer="glorot_uniform", activation="relu")`
#   model.add(Convolution2D(c, 3, 3, input_shape=(patch_height, patch_width, ch), activation='relu',init='glorot_uniform'))
# /home/saif/signality_codes/test/homography/deep_homography_estimation_dg.py:60: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), kernel_initializer="glorot_uniform", activation="relu")`
#   model.add(Convolution2D(c*2, 3, 3, activation='relu',init='glorot_uniform'))
# /home/saif/signality_codes/test/homography/deep_homography_estimation_dg.py:81: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(128, kernel_initializer="glorot_uniform", activation="relu")`
#   model.add(Dense(128, activation='relu',init='glorot_uniform'))
# ...

# %%
panorama()
# Out:
# /home/saif/signality_codes/test/homography/deep_homography_estimation_dg.py:59: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (3, 3), input_shape=(288, 512,..., kernel_initializer="glorot_uniform", activation="relu")`
#   model.add(Convolution2D(c, 3, 3, input_shape=(patch_height, patch_width, ch), activation='relu',init='glorot_uniform'))
# /home/saif/signality_codes/test/homography/deep_homography_estimation_dg.py:60: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), kernel_initializer="glorot_uniform", activation="relu")`
#   model.add(Convolution2D(c*2, 3, 3, activation='relu',init='glorot_uniform'))
# /home/saif/signality_codes/test/homography/deep_homography_estimation_dg.py:81: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(128, kernel_initializer="glorot_uniform", activation="relu")`
#   model.add(Dense(128, activation='relu',init='glorot_uniform'))
# ...

# %%
panorama()
# Out:
# /home/saif/signality_codes/test/homography/deep_homography_estimation_dg.py:59: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (3, 3), input_shape=(288, 512,..., kernel_initializer="glorot_uniform", activation="relu")`
#   model.add(Convolution2D(c, 3, 3, input_shape=(patch_height, patch_width, ch), activation='relu',init='glorot_uniform'))
# /home/saif/signality_codes/test/homography/deep_homography_estimation_dg.py:60: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), kernel_initializer="glorot_uniform", activation="relu")`
#   model.add(Convolution2D(c*2, 3, 3, activation='relu',init='glorot_uniform'))
# /home/saif/signality_codes/test/homography/deep_homography_estimation_dg.py:81: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(128, kernel_initializer="glorot_uniform", activation="relu")`
#   model.add(Dense(128, activation='relu',init='glorot_uniform'))
# ...
